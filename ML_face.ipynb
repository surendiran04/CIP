# %% [markdown]
# <a href="https://colab.research.google.com/github/surendiran04/CIP/blob/M-face/ML_face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install flask opencv-python mediapipe pyngrok flask_cors
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 43.7 MB/s eta 0:00:00
# ...

# %%
# !nohup python app.py &
# Out:
# nohup: appending output to 'nohup.out'

# %%
from flask import Flask
from flask_cors import CORS
from pyngrok import ngrok
import os
ngrok.kill()
# Set Ngrok Auth Token (Run this only once, remove if already set)
os.system("ngrok config add-authtoken 2u4LvrJIfGxxUQYdXQNhV60sAA8_2VTLHxWwvX9JV82E7XKZ3")

app = Flask(__name__)
CORS(app)

# ✅ Expose Public URL via Ngrok
public_url = ngrok.connect(5000).public_url
print(f"🚀 Public URL: {public_url}")
# Out:
# 🚀 Public URL: https://8c6c-35-187-147-161.ngrok-free.app

# %%
import os
import shutil
os.makedirs("templates",exist_ok=True)
shutil.move("index.html","templates/index.html")
# Out:
# 'templates/index.html'

# %%
# !cat nohup.out
# Out:
# 2025-03-14 17:29:04.350138: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741973344.393073    1880 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741973344.406069    1880 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-14 17:29:04.449124: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
