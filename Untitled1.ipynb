# %% [markdown]
# <a href="https://colab.research.google.com/github/surendiran04/CIP/blob/harini/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hi)")
# Out:
# Hi)
